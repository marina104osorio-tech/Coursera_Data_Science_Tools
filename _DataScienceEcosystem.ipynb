# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, the tools and ecosystems of data science are summarized.

# %% [markdown]
# ### Some of the popular languages used by data scientists are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ### Some of the popular libraries used by data scientists are:

# %% [markdown]
# #### 1. Python:

# %% [markdown]
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# #### 2. R:

# %% [markdown]
# 1. dplyr
# 2. ggplot2
# 3. tidyr
# 4. caret
# 5. shiny

# %% [markdown]
# | Data Science Tools|
# |----|
# | Python |
# | R |
# | SQL |
# | Orange |
# |Tableau|
# |Jupyter Notebook|
# |Power BI|

# %% [markdown]
# ### Some examples of arithmetic expessions in Python

# %% [markdown]
# A simple arithmetic expression to multiply and then add

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# To convert 200 minutes to hours, divide by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# __Learning objectives__

# %% [markdown]
# - Popular libraries used by data scientist
# - Popular languages used by data scientists
# - Convert minutes to hours
# - Arithmetic expressions

# %% [markdown]
# ## Author

# %% [markdown]
# Marina Osorio Dionis
